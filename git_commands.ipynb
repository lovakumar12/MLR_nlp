# %% [markdown]
# ## open your git hub
#
# https://github.com/

# %% [markdown]
# ### step-1 (create one repository)

# %%
# add the .gitignore ,README.md,LICENSE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## step-2

# %% [markdown]
# ### 1)clone the repository in git bash
# ### 2)open the folder with vs code
# ### 3)After creating come code in .py or  .ipynb files

# %% [markdown]
# ## step-3
# ### 1)open new terminal give the commands
#
# #### i)git init
# #### ii)git add .
# #### iii)git commit -m "first commit"
# #### iv)git push -u origin main
